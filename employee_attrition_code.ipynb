# %%
'''
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install xgboost
# !pip install imbalanced-learn
# !pip install shap
# !pip install streamlit
# !pip install plotly
'''
# Out:
# '\n!pip install pandas\n!pip install numpy\n!pip install matplotlib\n!pip install seaborn\n!pip install scikit-learn\n!pip install xgboost\n!pip install imbalanced-learn\n!pip install shap\n!pip install streamlit\n!pip install plotly\n'

# %% [markdown]
# # **1. Import Libraries:**

# %%
# ============================================
# Core & Data Handling
# ============================================
import pandas as pd
import numpy as np
from pathlib import Path
import pickle
import warnings
warnings.filterwarnings('ignore')

# ============================================
# Visualization
# ============================================
import matplotlib.pyplot as plt
import seaborn as sns

# ============================================
# Machine Learning - General
# ============================================
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score, recall_score, precision_score, f1_score, accuracy_score,
                              make_scorer, ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay)

# ============================================
# Machine Learning - Models
# ============================================
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (RandomForestClassifier, StackingClassifier)
from xgboost import XGBClassifier
import xgboost as xgb  # Redundant (already imported above), can remove

# ============================================
# Imbalanced Data Handling
# ============================================
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# ============================================
# Interpretability
# ============================================
import shap

# ============================================
# Global Configurations
# ============================================
pd.set_option('display.max_columns', None)
np.random.seed(42)

# %% [markdown]
# # **2. Load the Data and Initial inspection:**

# %% [markdown]
# **2.1 Load Dataset**

# %%
import pandas as pd
import os
from io import StringIO
import requests
def load_data(local_path, github_url=None):
  
    try:
        if os.path.exists(local_path):
            print(f"Data loaded successfully from Local path")
            return pd.read_csv(local_path)
        if github_url:
            print(f"File not found in local path, attempting from GitHub path")
            print(f"....")
            response = requests.get(github_url)
            response.raise_for_status()
            print(f"Data loaded successfully from GitHub path")
            return pd.read_csv(StringIO(response.text))
        print("no data")
        return None
    except Exception as e:
        print(f'Error in loading data, please verify the path or URL:')
    return None

localpath = "C:/Users/NITS/Downloads/employee_attrition_dataset_10000.csv"
github_url = "https://raw.githubusercontent.com/jaiswalnitish/Employee_attrition/refs/heads/main/employee_attrition_dataset_10000.csv"
employees = load_data(localpath, github_url)
# Out:
# Data loaded successfully from Local path

# %% [markdown]
# **2.2 Dataset Overview:**

# %% [markdown]
# *Structural Inspection*

# %%
# Shape and head
print("Dataset Dimensions:")
display(employees.shape)

print("\nFirst 5 Rows:")
display(employees.head())

# Column-wise info
print("\nData Types and Non-Null Counts:")
display(employees.info())
# Out:
# Dataset Dimensions:
# (10000, 26)
# First 5 Rows:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58    Male         Single    Finance    Manager          5
# 1            2   48  Female       Divorced         HR  Assistant          4
# 2            3   34  Female        Married  Marketing    Manager          4
# 3            4   27  Female       Divorced         HR    Manager          4
# 4            5   40    Male        Married         HR    Analyst          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  Years_in_Current_Role  \
# 0            7332           81                24                     12
# 1            6069           55                18                      7
# 2           11485           65                 6                      4
# 3           18707           28                12                      9
# 4           16398           92                 3                      9
#
#    Years_Since_Last_Promotion  Work_Life_Balance  Job_Satisfaction  \
# 0                           3                  1                 3
# 1                           5                  1                 2
# 2                           3                  4                 5
# 3                           1                  1                 1
# 4                           1                  3                 4
#
#    Performance_Rating  Training_Hours_Last_Year Overtime  Project_Count  \
# 0                   2                        74       No              9
# 1                   2                        24      Yes              9
# 2                   1                        63      Yes              3
# 3                   2                         4       No              9
# 4                   3                        62       No              1
#
#    Average_Hours_Worked_Per_Week  Absenteeism  Work_Environment_Satisfaction  \
# 0                             48           16                              4
# 1                             57           10                              4
# 2                             55            1                              1
# 3                             53            2                              3
# 4                             54           11                              1
#
#    Relationship_with_Manager  Job_Involvement  Distance_From_Home  \
# 0                          1                1                  49
# 1                          1                1                  25
# 2                          4                3                  21
# 3                          4                1                  46
# 4                          1                1                  43
#
#    Number_of_Companies_Worked Attrition
# 0                           3        No
# 1                           1        No
# 2                           1       Yes
# 3                           2        No
# 4                           4        No
# Data Types and Non-Null Counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
#  12  Work_Life_Balance              10000 non-null  int64
#  13  Job_Satisfaction               10000 non-null  int64
#  14  Performance_Rating             10000 non-null  int64
#  15  Training_Hours_Last_Year       10000 non-null  int64
#  16  Overtime                       10000 non-null  object
#  17  Project_Count                  10000 non-null  int64
#  18  Average_Hours_Worked_Per_Week  10000 non-null  int64
#  19  Absenteeism                    10000 non-null  int64
#  20  Work_Environment_Satisfaction  10000 non-null  int64
#  21  Relationship_with_Manager      10000 non-null  int64
#  22  Job_Involvement                10000 non-null  int64
#  23  Distance_From_Home             10000 non-null  int64
#  24  Number_of_Companies_Worked     10000 non-null  int64
#  25  Attrition                      10000 non-null  object
# dtypes: int64(20), object(6)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# *Missing Value Check*

# %%
# Missing values
missing_data = employees.isnull().sum()
print("Missing Values Per Column:")
print(missing_data)

# Handle missing data (if any)
if missing_data.any():
    employees.dropna(inplace=True) 
    print(f"Dropped rows with missing values. New shape: {employees.shape}")
# Out:
# Missing Values Per Column:
# Employee_ID                      0
# Age                              0
# Gender                           0
# Marital_Status                   0
# Department                       0
# Job_Role                         0
# Job_Level                        0
# Monthly_Income                   0
# Hourly_Rate                      0
# Years_at_Company                 0
# Years_in_Current_Role            0
# Years_Since_Last_Promotion       0
# Work_Life_Balance                0
# Job_Satisfaction                 0
# Performance_Rating               0
# Training_Hours_Last_Year         0
# Overtime                         0
# Project_Count                    0
# Average_Hours_Worked_Per_Week    0
# Absenteeism                      0
# Work_Environment_Satisfaction    0
# Relationship_with_Manager        0
# Job_Involvement                  0
# Distance_From_Home               0
# Number_of_Companies_Worked       0
# Attrition                        0
# dtype: int64

# %% [markdown]
# **2.3 Data Quality Check**

# %% [markdown]
# *Data duplicacy check*

# %%
print(f"Total duplicate rows: {employees.duplicated().sum()}")
employees.drop_duplicates(inplace=True)

print(f"Duplicate Employee ID: {employees['Employee_ID'].duplicated().sum()}")
# Out:
# Total duplicate rows: 0
# Duplicate Employee ID: 0

# %% [markdown]
# *Data Consistency*

# %%
employees['Years_Since_Last_Promotion']=employees[['Years_Since_Last_Promotion','Years_at_Company']].min(axis=1)

#Checking categorical values
cat_cols = employees.select_dtypes(include='object').columns
print("\nCategorical Value Checks:")
for col in cat_cols:
    print(f"{col}: {employees[col].unique()}")
# Out:
# Categorical Value Checks:
# Gender: ['Male' 'Female']
# Marital_Status: ['Single' 'Divorced' 'Married']
# Department: ['Finance' 'HR' 'Marketing' 'Sales' 'IT']
# Job_Role: ['Manager' 'Assistant' 'Analyst' 'Executive']
# Overtime: ['No' 'Yes']
# Attrition: ['No' 'Yes']

# %% [markdown]
# **2.4 Summary of Data**

# %%
#data summary
print("Numerical data summary:")
display(employees.describe())

#Target variable
print("\nAttrition Distribution:")
display(employees['Attrition'].value_counts())
# Out:
# Numerical data summary:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.047800
# std            8.431657               4.042903                    2.782353
# min            1.000000               1.000000                    0.000000
# 25%            8.000000               4.000000                    2.000000
# 50%           15.000000               7.000000                    4.000000
# 75%           22.000000              11.000000                    6.000000
# max           29.000000              14.000000                    9.000000
#
#        Work_Life_Balance  Job_Satisfaction  Performance_Rating  \
# count       10000.000000      10000.000000        10000.000000
# mean            2.502400          3.038000            2.507700
# std             1.112348          1.414764            1.120833
# min             1.000000          1.000000            1.000000
# 25%             2.000000          2.000000            2.000000
# 50%             2.000000          3.000000            3.000000
# 75%             3.000000          4.000000            4.000000
# max             4.000000          5.000000            4.000000
#
#        Training_Hours_Last_Year  Project_Count  Average_Hours_Worked_Per_Week  \
# count              10000.000000   10000.000000                   10000.000000
# mean                  49.588900       4.984400                      44.473500
# std                   28.801393       2.580043                       8.611662
# min                    0.000000       1.000000                      30.000000
# 25%                   25.000000       3.000000                      37.000000
# 50%                   49.000000       5.000000                      45.000000
# 75%                   75.000000       7.000000                      52.000000
# max                   99.000000       9.000000                      59.000000
#
#         Absenteeism  Work_Environment_Satisfaction  Relationship_with_Manager  \
# count  10000.000000                   10000.000000               10000.000000
# mean       9.410200                       2.493100                   2.491400
# std        5.760335                       1.120927                   1.115101
# min        0.000000                       1.000000                   1.000000
# 25%        4.000000                       1.000000                   1.000000
# 50%        9.000000                       2.000000                   2.000000
# 75%       14.000000                       4.000000                   3.000000
# max       19.000000                       4.000000                   4.000000
#
#        Job_Involvement  Distance_From_Home  Number_of_Companies_Worked
# count     10000.000000        10000.000000                10000.000000
# mean          2.505400           25.272000                    2.516600
# std           1.116018           14.219474                    1.113934
# min           1.000000            1.000000                    1.000000
# 25%           2.000000           13.000000                    2.000000
# 50%           3.000000           25.000000                    2.000000
# 75%           3.000000           37.000000                    4.000000
# max           4.000000           49.000000                    4.000000
# Attrition Distribution:
# Attrition
# No     8003
# Yes    1997
# Name: count, dtype: int64

# %% [markdown]
# **2.5 Exploratory Data Analysis (EDA)**

# %%
#employees['Attrition'] = employees['Attrition'].cat.set_categories(['No', 'Yes'])  

custom_palette = ['#578FCA', '#E1556A']  # No = Blue, Yes = Red

# ----------------------------
# 1. Numerical Attributes
# ----------------------------
num_features = [
    'Age','Monthly_Income','Years_at_Company',
    'Years_in_Current_Role','Years_Since_Last_Promotion'
]

for col in num_features:
    plt.figure(figsize=(7,5))
    ax = sns.histplot(
        data=employees, x=col, hue="Attrition", hue_order=['No','Yes'],
        bins=30, palette=custom_palette, multiple="stack"
    )

    # Add labels outside each bar segment
    

    plt.title(f"{col} Distribution by Attrition")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.legend(title="Attrition", labels=['No','Yes'], bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# ----------------------------
# 2. Categorical Attributes
# ----------------------------
cat_features = [
    'Gender','Department','Job_Role','Job_Level',
    'Work_Life_Balance','Job_Satisfaction','Performance_Rating',
    'Work_Environment_Satisfaction','Relationship_with_Manager','Job_Involvement'
]

for col in cat_features:
    ct = pd.crosstab(employees[col], employees['Attrition'])[['No','Yes']]  # force order
    ax = ct.plot(kind='bar', stacked=True, figsize=(8,5), color=custom_palette)

    # Add labels inside bar segments
    for c in ax.containers:
        ax.bar_label(c, label_type='center', fontsize=9, color='white')

    plt.title(f"Attrition by {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.legend(title="Attrition", labels=['No','Yes'], bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(data=employees, x='Attrition', palette=['#578FCA', '#E1556A'])

# Calculate total for percentage conversion
total = len(employees)

# Annotate each bar with percentage
for p in ax.patches:
    height = p.get_height()
    percent = 100 * height / total
    ax.annotate(f'{percent:.1f}%', 
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10, color='black')

plt.title("Attrition Distribution(%)")
plt.ylabel("Count")
plt.show()

# %%
# Attributes to plot
attributes = ['Gender', 'Department', 'Job_Role', 'Job_Level']
titles = ['Gender Distribution', 'Department Distribution', 'Job Role Distribution', 'Job Level Distribution']
mycolor = ['#578FCA', '#E2EFF1', '#555273', '#E23E57', '#274c77']

# Create 2x2 subplot for the main attributes
figure, axis = plt.subplots(2, 2, figsize=(8, 10))

for i, attr in enumerate(attributes):
    data = employees[attr].value_counts()
    row, col = divmod(i, 2)
    axis[row, col].pie(data, labels=data.index, autopct='%1.1f%%', colors=mycolor, startangle=90)
    axis[row, col].set_title(titles[i])

# Separate plot for Marital Status
figure, axis = plt.subplots(1, 1, figsize=(3, 3))
marital_status = employees['Marital_Status'].value_counts()
axis.pie(marital_status, labels=marital_status.index, autopct='%1.1f%%', colors=mycolor, startangle=90)
axis.set_title('Marital Status Distribution')

plt.tight_layout()
plt.show()

# %%
employees.groupby(["Department","Gender"])["Attrition"].count().sort_values(ascending=False)
# Out:
# Department  Gender
# Marketing   Female    1070
#             Male      1063
# Sales       Male      1025
# Finance     Female    1014
# IT          Female    1007
# HR          Male       985
# Sales       Female     983
# Finance     Male       976
# HR          Female     968
# IT          Male       909
# Name: Attrition, dtype: int64

# %%
#department w.r.t attrition percentage
pd.crosstab(
    employees['Department'], 
    employees['Attrition'], 
    normalize='index'  # Normalize by row to show % attrition
).mul(100).round(1).astype(str) + '%'
# Out:
# Attrition      No    Yes
# Department
# Finance     79.1%  20.9%
# HR          80.5%  19.5%
# IT          79.6%  20.4%
# Marketing   80.6%  19.4%
# Sales       80.2%  19.8%

# %% [markdown]
# # **3. Data Preprocessing:**

# %% [markdown]
# **3.1 Handle data inconsistencies:**

# %%
#ensure Years since last promotion is less than or equal to year at same company
employees['Years_Since_Last_Promotion']=employees[['Years_Since_Last_Promotion','Years_at_Company']].min(axis=1)

#validate age field
employees= employees[employees['Age'] >= 18]

# %% [markdown]
# **3.2 Handle categorical data:**

# %% [markdown]
# *Label encoding (Binary features)*

# %%
#
binary_categorical_col1 = ['Attrition', 'Overtime']
le = LabelEncoder()
for cols in binary_categorical_col1:
    employees[cols] = le.fit_transform(employees[cols])

employees['Attrition'].value_counts()
# Out:
# Attrition
# 0    8003
# 1    1997
# Name: count, dtype: int64

# %% [markdown]
# *One-hot encoding (Nominal features)*

# %%
nominal_categorical_cols = employees.select_dtypes(include=['object']).columns
# One-hot encode categorical columns
employees = pd.get_dummies(employees, columns=nominal_categorical_cols, drop_first=True)

# %%
employees.rename({'Monthly_Income':'id1'}, axis=1, inplace=True)
employees=employees.astype(int)
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Job_Level                      10000 non-null  int64
#  3   id1                            10000 non-null  int64
#  4   Hourly_Rate                    10000 non-null  int64
#  5   Years_at_Company               10000 non-null  int64
#  6   Years_in_Current_Role          10000 non-null  int64
#  7   Years_Since_Last_Promotion     10000 non-null  int64
#  8   Work_Life_Balance              10000 non-null  int64
#  9   Job_Satisfaction               10000 non-null  int64
#  10  Performance_Rating             10000 non-null  int64
#  11  Training_Hours_Last_Year       10000 non-null  int64
#  12  Overtime                       10000 non-null  int64
#  13  Project_Count                  10000 non-null  int64
#  14  Average_Hours_Worked_Per_Week  10000 non-null  int64
#  15  Absenteeism                    10000 non-null  int64
#  16  Work_Environment_Satisfaction  10000 non-null  int64
#  17  Relationship_with_Manager      10000 non-null  int64
#  18  Job_Involvement                10000 non-null  int64
#  19  Distance_From_Home             10000 non-null  int64
#  20  Number_of_Companies_Worked     10000 non-null  int64
#  21  Attrition                      10000 non-null  int64
#  22  Gender_Male                    10000 non-null  int64
#  23  Marital_Status_Married         10000 non-null  int64
#  24  Marital_Status_Single          10000 non-null  int64
#  25  Department_HR                  10000 non-null  int64
#  26  Department_IT                  10000 non-null  int64
#  27  Department_Marketing           10000 non-null  int64
#  28  Department_Sales               10000 non-null  int64
#  29  Job_Role_Assistant             10000 non-null  int64
#  30  Job_Role_Executive             10000 non-null  int64
#  31  Job_Role_Manager               10000 non-null  int64
# dtypes: int64(32)
# memory usage: 2.4 MB

# %% [markdown]
# # **4. Model Preparation**

# %% [markdown]
# **4.1 Feature Selection**

# %% [markdown]
# *Validate Correlation relation*

# %%
plt.figure(figsize=(24,12))
sns.heatmap(employees.corr(), annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
#print(corr_matrix['Attrition'].sort_values(ascending=False))
employees.corr()['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                        1.000000
# Job_Role_Assistant               0.021360
# Work_Life_Balance                0.015227
# Job_Involvement                  0.014954
# Performance_Rating               0.011856
# Job_Level                        0.011415
# Distance_From_Home               0.011361
# Age                              0.007798
# Gender_Male                      0.007448
# Project_Count                    0.006802
# Years_in_Current_Role            0.005120
# Department_IT                    0.004687
# Marital_Status_Single            0.003187
# Years_at_Company                 0.002682
# Overtime                         0.002537
# Job_Satisfaction                 0.002142
# Job_Role_Executive               0.001474
# Absenteeism                      0.000514
# id1                              0.000135
# Training_Hours_Last_Year        -0.000539
# Years_Since_Last_Promotion      -0.001390
# Department_Sales                -0.001872
# Average_Hours_Worked_Per_Week   -0.002457
# Relationship_with_Manager       -0.004111
# Hourly_Rate                     -0.005494
# Department_HR                   -0.005688
# Department_Marketing            -0.007914
# Number_of_Companies_Worked      -0.008230
# Employee_ID                     -0.008766
# Work_Environment_Satisfaction   -0.011096
# Marital_Status_Married          -0.013218
# Job_Role_Manager                -0.026933
# Name: Attrition, dtype: float64

# %% [markdown]
# **4.2 Feature selection**

# %%
drop_cols = {
    "HR_Only": [
        'Employee_ID', 'Age', 'Hourly_Rate', 'Project_Count',
        'Training_Hours_Last_Year', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
        'Number_of_Companies_Worked', 'Work_Life_Balance', 'Job_Satisfaction','Work_Environment_Satisfaction',
        'Relationship_with_Manager', 'id1', 'Job_Involvement'  
    ],
    "HR_Plus_Survey": [
        'Employee_ID', 'Age', 'Hourly_Rate', 'Project_Count',
        'Training_Hours_Last_Year', 'id1', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
        'Number_of_Companies_Worked'        # Only basic columns to drop (retain Survey features)
    ]
}

# %%
#preprating data with train test split into 80-20 data size
def data_preparation(df, scenario):
    """
    Prepares dataset for specified scenario with proper:
    - Feature selection
    - Train-test splitting
    - SMOTE resampling
    - Feature scaling
    """
    # Feature selection
    df_prepped = df.drop(columns=drop_cols[scenario])
    
    # Separate features and target
    X = df_prepped.drop(columns=['Attrition'])
    y = df_prepped['Attrition']
    X,y = SMOTE(sampling_strategy='minority', random_state=42).fit_resample(X, y)
    # Train-test split (stratified)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, 
        test_size=0.2, 
        stratify=y, 
        random_state=42
    )
    
    # Scale features
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    return {
        'X_train': X_train,
        'X_test': X_test,
        'X_train_scaled': X_train_scaled,
        'X_test_scaled': X_test_scaled,
        'y_train': y_train,
        'y_test': y_test,
        'feature_names': X.columns,
        'scaler': scaler
    }
#print(f"Class balance in train: {y_train.value_counts(normalize=True)}")
#print(f"Class balance in test: {y_test.value_counts(normalize=True)}")

# %%
# ============================================
# Initialize machine learning models
# ============================================
def init_models(scale_pos_weight=None):
    """Initialize all models with scenario-specific parameters"""
    models = {}
    
    # Logistic Regression
    models["Logistic_Regression"] = LogisticRegression(
        class_weight='balanced',
        max_iter=1000,
        solver='liblinear',
        random_state=42,
    )
    
    # Random Forest
    models["Random_Forest"] = RandomForestClassifier(
        class_weight='balanced',
        max_depth=5,
        n_estimators=150,
        random_state=42
    )
    
    # Basic XGBoost
    models["XGBoost"] = XGBClassifier(
        eval_metric='aucpr',
        max_depth=5,
        random_state=42,
        scale_pos_weight=scale_pos_weight if scale_pos_weight else 1
    )
    
    # Tuned XGBoost
    models["XGBoost_Tuned"] = XGBClassifier(
        learning_rate=0.05,
        max_depth=8,
        n_estimators=1000,
        reg_alpha=0.1,
        reg_lambda=1.0,
        gamma=0.1,
        early_stopping_rounds=10,
        random_state=42,
        scale_pos_weight=scale_pos_weight if scale_pos_weight else 1
    )
    
    # Stacked Model
    models["Stacked_Model"] = StackingClassifier(
        estimators=[
            ('rf', models["Random_Forest"]),
            ('xgb', models["XGBoost"])
        ],
        final_estimator=LogisticRegression(
            class_weight='balanced',
            max_iter=1000,
            random_state=42
        ),
        cv=5
    )
    
    return models

# %%
# ============================================
# Model Training & Evaluation
# ============================================

def train_and_evaluate(models, data, scenario_name):
    """Handles proper data scaling per model type"""
    results = {}

    for name, model in models.items():
        print(f"\n{'='*50}\n{scenario_name} - Model {name}\n{'='*50}")

        # Select proper data based on model type
        if name == "Logistic_Regression":
            X_train = data['X_train_scaled']
            X_test = data['X_test_scaled']
        else:
            X_train = data['X_train']
            X_test = data['X_test']

        # Special handling for XGBoost early stopping
        if 'XGBoost' in name:
            model.fit(
                X_train, data['y_train'],
                eval_set=[(X_test, data['y_test'])],
                verbose=100
            )
        else:
            model.fit(X_train, data['y_train'])

        # Predictions (use correct X_test version)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:,1] if hasattr(model, 'predict_proba') else None

        # Store metrics
        results[name] = {
            'precision': precision_score(data['y_test'], y_pred, pos_label=1),
            'recall': recall_score(data['y_test'], y_pred, pos_label=1),
            'accuracy': accuracy_score(data['y_test'], y_pred),
            'roc_auc': roc_auc_score(data['y_test'], y_proba) if y_proba is not None else None,
            'f1': f1_score(data['y_test'], y_pred, pos_label=1)
        }
        
        print("\nClassification Report:")
        print(classification_report(data['y_test'], y_pred))

        # Confusion Matrix
        cm = confusion_matrix(data['y_test'], y_pred, labels=[0, 1])
        displ = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Attrition', 'Attrition'])
        displ.plot(cmap='Blues')
        plt.title(f"Confusion Matrix: {scenario_name} - {name}")
        plt.tight_layout()
        plt.show()
        
        # For SHAP analysis using XGBOost_tuned
        if name == "XGBoost_Tuned": 
            global final_model, X_test_shap
            final_model = model
            X_test_shap = data['X_test']  

    return pd.DataFrame(results).T

# %%
# ============================================
# Scenario Comparison Workflow
# ============================================

# Prepare both datasets
hr_data = data_preparation(employees, "HR_Only")
hr_eng_data = data_preparation(employees, "HR_Plus_Survey")

# Initialize models with class weights
def calculate_scale_pos_weight(y_train):
    """Safely calculate class weight ratio"""
    if y_train is None:
        return None
    # Convert to numpy array if it's a pandas Series
    y_train_values = y_train.values if hasattr(y_train, 'values') else y_train
    return sum(y_train_values == 0) / sum(y_train_values == 1)

models_hr = init_models(calculate_scale_pos_weight(hr_data['y_train']))
models_hr_eng = init_models(calculate_scale_pos_weight(hr_eng_data['y_train']))

# Ensure X_test is a DataFrame with feature names for both scenarios
if not isinstance(hr_data['X_test'], pd.DataFrame):
    hr_data['X_test'] = pd.DataFrame(hr_data['X_test'], columns=hr_data['feature_names'])
if not isinstance(hr_eng_data['X_test'], pd.DataFrame):
    hr_eng_data['X_test'] = pd.DataFrame(hr_eng_data['X_test'], columns=hr_eng_data['feature_names'])

# Also ensure X_train is a DataFrame with feature names for both scenarios
if not isinstance(hr_data['X_train'], pd.DataFrame):
    hr_data['X_train'] = pd.DataFrame(hr_data['X_train'], columns=hr_data['feature_names'])
if not isinstance(hr_eng_data['X_train'], pd.DataFrame):
    hr_eng_data['X_train'] = pd.DataFrame(hr_eng_data['X_train'], columns=hr_eng_data['feature_names'])

# Train and evaluate for both scenarios
hr_results = train_and_evaluate(models_hr, hr_data, "HR_Only")
hr_eng_results = train_and_evaluate(models_hr_eng, hr_eng_data, "HR_Plus_Survey")
# Out:
# ==================================================
# HR_Only - Model Logistic_Regression
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77      1601
#            1       0.78      0.71      0.75      1601
#
#     accuracy                           0.76      3202
#    macro avg       0.76      0.76      0.76      3202
# weighted avg       0.76      0.76      0.76      3202
# ==================================================
# HR_Only - Model Random_Forest
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77      1601
#            1       0.79      0.71      0.75      1601
#
#     accuracy                           0.76      3202
#    macro avg       0.76      0.76      0.76      3202
# weighted avg       0.76      0.76      0.76      3202
# ==================================================
# HR_Only - Model XGBoost
# ==================================================
# [0]	validation_0-aucpr:0.75601
# [99]	validation_0-aucpr:0.87724
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      1601
#            1       0.81      0.76      0.78      1601
#
#     accuracy                           0.79      3202
#    macro avg       0.79      0.79      0.79      3202
# weighted avg       0.79      0.79      0.79      3202
# ==================================================
# HR_Only - Model XGBoost_Tuned
# ==================================================
# [0]	validation_0-logloss:0.67799
# [100]	validation_0-logloss:0.46028
# [200]	validation_0-logloss:0.44611
# [252]	validation_0-logloss:0.44179
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      1601
#            1       0.84      0.76      0.80      1601
#
#     accuracy                           0.81      3202
#    macro avg       0.81      0.81      0.81      3202
# weighted avg       0.81      0.81      0.81      3202
# ==================================================
# HR_Only - Model Stacked_Model
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      1601
#            1       0.81      0.76      0.78      1601
#
#     accuracy                           0.79      3202
#    macro avg       0.79      0.79      0.79      3202
# weighted avg       0.79      0.79      0.79      3202
# ==================================================
# HR_Plus_Survey - Model Logistic_Regression
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77      1601
#            1       0.78      0.72      0.75      1601
#
#     accuracy                           0.76      3202
#    macro avg       0.76      0.76      0.76      3202
# weighted avg       0.76      0.76      0.76      3202
# ==================================================
# HR_Plus_Survey - Model Random_Forest
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79      1601
#            1       0.82      0.71      0.76      1601
#
#     accuracy                           0.78      3202
#    macro avg       0.78      0.78      0.77      3202
# weighted avg       0.78      0.78      0.77      3202
# ==================================================
# HR_Plus_Survey - Model XGBoost
# ==================================================
# [0]	validation_0-aucpr:0.75243
# [99]	validation_0-aucpr:0.89146
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      1601
#            1       0.83      0.77      0.79      1601
#
#     accuracy                           0.80      3202
#    macro avg       0.80      0.80      0.80      3202
# weighted avg       0.80      0.80      0.80      3202
# ==================================================
# HR_Plus_Survey - Model XGBoost_Tuned
# ==================================================
# [0]	validation_0-logloss:0.67816
# [100]	validation_0-logloss:0.43586
# [200]	validation_0-logloss:0.41781
# [240]	validation_0-logloss:0.41539
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.84      1601
#            1       0.87      0.77      0.81      1601
#
#     accuracy                           0.83      3202
#    macro avg       0.83      0.83      0.83      3202
# weighted avg       0.83      0.83      0.83      3202
# ==================================================
# HR_Plus_Survey - Model Stacked_Model
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      1601
#            1       0.83      0.76      0.80      1601
#
#     accuracy                           0.80      3202
#    macro avg       0.81      0.80      0.80      3202
# weighted avg       0.81      0.80      0.80      3202

# %%
# ============================================
# Results Comparison
# ============================================

def compare_results(hr_df, hr_eng_df):
    """Generate side-by-side comparison with deltas"""
    comparison = pd.concat({
        'HR_Only': hr_df,
        'HR_Plus_Survey': hr_eng_df
    }, axis=1)
    
    # Calculate deltas
    for metric in ['precision', 'recall', 'accuracy', 'roc_auc']:
        comparison[('Delta', metric)] = (
            comparison[('HR_Plus_Survey', metric)] - 
            comparison[('HR_Only', metric)]
        )
    
    # Format for display
    return comparison.sort_values(
        by=[('HR_Plus_Survey', 'recall')], 
        ascending=False
    )

# Generate final comparison
results_comparison = compare_results(hr_results, hr_eng_results)
print("\nFinal Comparison:")
display(results_comparison.style.background_gradient(
    cmap='RdYlGn', 
    subset=[col for col in results_comparison.columns if 'Delta' in col],
    vmin=-0.1, 
    vmax=0.1
))
# Out:
# Final Comparison:
# <style type="text/css">
# #T_349aa_row0_col10 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_349aa_row0_col11 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_349aa_row0_col12 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_349aa_row0_col13, #T_349aa_row2_col13 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_349aa_row1_col10 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_349aa_row1_col11, #T_349aa_row3_col11 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_349aa_row1_col12, #T_349aa_row4_col13 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_349aa_row1_col13 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_349aa_row2_col10 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_349aa_row2_col11 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_349aa_row2_col12 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_349aa_row3_col10 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_349aa_row3_col12 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_349aa_row3_col13 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_349aa_row4_col10 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_349aa_row4_col11 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_349aa_row4_col12 {
#   background-color: #e3f399;
#   color: #000000;
# }
# </style>
# <table id="T_349aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_349aa_level0_col0" class="col_heading level0 col0" colspan="5">HR_Only</th>
#       <th id="T_349aa_level0_col5" class="col_heading level0 col5" colspan="5">HR_Plus_Survey</th>
#       <th id="T_349aa_level0_col10" class="col_heading level0 col10" colspan="4">Delta</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_349aa_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_349aa_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_349aa_level1_col2" class="col_heading level1 col2" >accuracy</th>
#       <th id="T_349aa_level1_col3" class="col_heading level1 col3" >roc_auc</th>
#       <th id="T_349aa_level1_col4" class="col_heading level1 col4" >f1</th>
#       <th id="T_349aa_level1_col5" class="col_heading level1 col5" >precision</th>
#       <th id="T_349aa_level1_col6" class="col_heading level1 col6" >recall</th>
#       <th id="T_349aa_level1_col7" class="col_heading level1 col7" >accuracy</th>
#       <th id="T_349aa_level1_col8" class="col_heading level1 col8" >roc_auc</th>
#       <th id="T_349aa_level1_col9" class="col_heading level1 col9" >f1</th>
#       <th id="T_349aa_level1_col10" class="col_heading level1 col10" >precision</th>
#       <th id="T_349aa_level1_col11" class="col_heading level1 col11" >recall</th>
#       <th id="T_349aa_level1_col12" class="col_heading level1 col12" >accuracy</th>
#       <th id="T_349aa_level1_col13" class="col_heading level1 col13" >roc_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_349aa_level0_row0" class="row_heading level0 row0" >XGBoost_Tuned</th>
#       <td id="T_349aa_row0_col0" class="data row0 col0" >0.840220</td>
#       <td id="T_349aa_row0_col1" class="data row0 col1" >0.762024</td>
#       <td id="T_349aa_row0_col2" class="data row0 col2" >0.808557</td>
#       <td id="T_349aa_row0_col3" class="data row0 col3" >0.869932</td>
#       <td id="T_349aa_row0_col4" class="data row0 col4" >0.799214</td>
#       <td id="T_349aa_row0_col5" class="data row0 col5" >0.868551</td>
#       <td id="T_349aa_row0_col6" class="data row0 col6" >0.767645</td>
#       <td id="T_349aa_row0_col7" class="data row0 col7" >0.825734</td>
#       <td id="T_349aa_row0_col8" class="data row0 col8" >0.882255</td>
#       <td id="T_349aa_row0_col9" class="data row0 col9" >0.814987</td>
#       <td id="T_349aa_row0_col10" class="data row0 col10" >0.028331</td>
#       <td id="T_349aa_row0_col11" class="data row0 col11" >0.005621</td>
#       <td id="T_349aa_row0_col12" class="data row0 col12" >0.017177</td>
#       <td id="T_349aa_row0_col13" class="data row0 col13" >0.012322</td>
#     </tr>
#     <tr>
#       <th id="T_349aa_level0_row1" class="row_heading level0 row1" >XGBoost</th>
#       <td id="T_349aa_row1_col0" class="data row1 col0" >0.806645</td>
#       <td id="T_349aa_row1_col1" class="data row1 col1" >0.758276</td>
#       <td id="T_349aa_row1_col2" class="data row1 col2" >0.788257</td>
#       <td id="T_349aa_row1_col3" class="data row1 col3" >0.854651</td>
#       <td id="T_349aa_row1_col4" class="data row1 col4" >0.781713</td>
#       <td id="T_349aa_row1_col5" class="data row1 col5" >0.826586</td>
#       <td id="T_349aa_row1_col6" class="data row1 col6" >0.765147</td>
#       <td id="T_349aa_row1_col7" class="data row1 col7" >0.802311</td>
#       <td id="T_349aa_row1_col8" class="data row1 col8" >0.867217</td>
#       <td id="T_349aa_row1_col9" class="data row1 col9" >0.794681</td>
#       <td id="T_349aa_row1_col10" class="data row1 col10" >0.019941</td>
#       <td id="T_349aa_row1_col11" class="data row1 col11" >0.006871</td>
#       <td id="T_349aa_row1_col12" class="data row1 col12" >0.014054</td>
#       <td id="T_349aa_row1_col13" class="data row1 col13" >0.012566</td>
#     </tr>
#     <tr>
#       <th id="T_349aa_level0_row2" class="row_heading level0 row2" >Stacked_Model</th>
#       <td id="T_349aa_row2_col0" class="data row2 col0" >0.806129</td>
#       <td id="T_349aa_row2_col1" class="data row2 col1" >0.755778</td>
#       <td id="T_349aa_row2_col2" class="data row2 col2" >0.787008</td>
#       <td id="T_349aa_row2_col3" class="data row2 col3" >0.853366</td>
#       <td id="T_349aa_row2_col4" class="data row2 col4" >0.780142</td>
#       <td id="T_349aa_row2_col5" class="data row2 col5" >0.833676</td>
#       <td id="T_349aa_row2_col6" class="data row2 col6" >0.760775</td>
#       <td id="T_349aa_row2_col7" class="data row2 col7" >0.804497</td>
#       <td id="T_349aa_row2_col8" class="data row2 col8" >0.865121</td>
#       <td id="T_349aa_row2_col9" class="data row2 col9" >0.795558</td>
#       <td id="T_349aa_row2_col10" class="data row2 col10" >0.027546</td>
#       <td id="T_349aa_row2_col11" class="data row2 col11" >0.004997</td>
#       <td id="T_349aa_row2_col12" class="data row2 col12" >0.017489</td>
#       <td id="T_349aa_row2_col13" class="data row2 col13" >0.011755</td>
#     </tr>
#     <tr>
#       <th id="T_349aa_level0_row3" class="row_heading level0 row3" >Logistic_Regression</th>
#       <td id="T_349aa_row3_col0" class="data row3 col0" >0.781656</td>
#       <td id="T_349aa_row3_col1" class="data row3 col1" >0.713304</td>
#       <td id="T_349aa_row3_col2" class="data row3 col2" >0.757027</td>
#       <td id="T_349aa_row3_col3" class="data row3 col3" >0.814136</td>
#       <td id="T_349aa_row3_col4" class="data row3 col4" >0.745918</td>
#       <td id="T_349aa_row3_col5" class="data row3 col5" >0.784888</td>
#       <td id="T_349aa_row3_col6" class="data row3 col6" >0.720175</td>
#       <td id="T_349aa_row3_col7" class="data row3 col7" >0.761399</td>
#       <td id="T_349aa_row3_col8" class="data row3 col8" >0.822596</td>
#       <td id="T_349aa_row3_col9" class="data row3 col9" >0.751140</td>
#       <td id="T_349aa_row3_col10" class="data row3 col10" >0.003231</td>
#       <td id="T_349aa_row3_col11" class="data row3 col11" >0.006871</td>
#       <td id="T_349aa_row3_col12" class="data row3 col12" >0.004372</td>
#       <td id="T_349aa_row3_col13" class="data row3 col13" >0.008460</td>
#     </tr>
#     <tr>
#       <th id="T_349aa_level0_row4" class="row_heading level0 row4" >Random_Forest</th>
#       <td id="T_349aa_row4_col0" class="data row4 col0" >0.791899</td>
#       <td id="T_349aa_row4_col1" class="data row4 col1" >0.708307</td>
#       <td id="T_349aa_row4_col2" class="data row4 col2" >0.761087</td>
#       <td id="T_349aa_row4_col3" class="data row4 col3" >0.820502</td>
#       <td id="T_349aa_row4_col4" class="data row4 col4" >0.747774</td>
#       <td id="T_349aa_row4_col5" class="data row4 col5" >0.817855</td>
#       <td id="T_349aa_row4_col6" class="data row4 col6" >0.709557</td>
#       <td id="T_349aa_row4_col7" class="data row4 col7" >0.775765</td>

# %% [markdown]
# ================================
# ==============================================
# ================================

# %% [markdown]
# ## New Section SHAP

# %%
# HR+Survey data is considered for shap analysis
data = hr_eng_data  
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']
feature_names = data['feature_names']

# Initialize JS visualization
shap.initjs()

scale_pos_weight = sum(y_train == 0) / sum(y_train == 1)
# 1. Train model (assuming X_train, y_train, X_test, y_test are defined)
final_model = XGBClassifier(
    colsample_bytree=1.0,
    learning_rate=0.05,
    max_depth=8,
    min_child_weight=1,
    n_estimators=1000,
    subsample=0.9,
    scale_pos_weight=scale_pos_weight,
    eval_metric='aucpr',
    early_stopping_rounds=10,
    random_state=42,
    reg_alpha=0.1,
    reg_lambda=1.0,
    gamma=0.1
)

final_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

# 2. Create SHAP explainer and calculate values
explainer = shap.TreeExplainer(final_model)
shap_values = explainer.shap_values(X_test)

# Handle different SHAP output formats
if hasattr(shap_values, 'values'):
    shap_array = shap_values.values
else:
    shap_array = shap_values

if isinstance(shap_array, list):
    shap_array = shap_array[1]  # For binary classification





# ============================================
# DEPARTMENT-SPECIFIC ANALYSIS
# ============================================

print("\n" + "="*50)
print("DEPARTMENT-SPECIFIC ANALYSIS")
print("="*50)

departments = ['HR', 'IT', 'Marketing', 'Sales']

for dept in departments:
    dept_col = f'Department_{dept}'
    if dept_col in data['feature_names']:
        dept_idx = list(data['feature_names']).index(dept_col)
        dept_mask = X_test.iloc[:, dept_idx] == 1

        if sum(dept_mask) > 10:  # Minimum samples threshold
            print(f"\n{dept} Department Insights:")

            # Get indices of non-department features and current department
            non_dept_indices = [i for i, name in enumerate(data['feature_names'])
                               if not name.startswith('Department_')]
            current_dept_index = list(data['feature_names']).index(dept_col)

            # Filter SHAP values and features for this department
            filtered_indices = non_dept_indices + [current_dept_index]
            filtered_shap = shap_array[dept_mask].iloc[0, filtered_indices] if isinstance(shap_array[dept_mask], pd.DataFrame) else shap_array[dept_mask][0][filtered_indices]
            filtered_features = [data['feature_names'][i] for i in filtered_indices]
            filtered_values = X_test[dept_mask].iloc[0, filtered_indices]

            # Create waterfall plot
            shap.plots.waterfall(
                shap.Explanation(
                    values=filtered_shap,
                    base_values=explainer.expected_value,
                    feature_names=filtered_features,
                    data=None
                ),
                max_display=15,
                show=False
            )
            shap_series = pd.Series(filtered_shap, index=filtered_features)
            top_red_features = shap_series[shap_series > 0].sort_values(ascending=False).head(3)

            plt.title(f"{dept} Department: Key Drivers", pad=20)
            plt.tight_layout()
            plt.show()
            # 🔍 Show top 3 red bar variables (positive SHAP values) Actionable Insight
            print(f"\nTop 3 attrition risk drivers for {dept} Department:")
            for feature, value in top_red_features.items():
                print(f"- {feature}: SHAP value = {value:.4f}")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# [0]	validation_0-aucpr:0.79624
# [1]	validation_0-aucpr:0.82975
# [2]	validation_0-aucpr:0.83373
# [3]	validation_0-aucpr:0.84553
# [4]	validation_0-aucpr:0.85345
# [5]	validation_0-aucpr:0.85375
# [6]	validation_0-aucpr:0.85720
# [7]	validation_0-aucpr:0.85878
# [8]	validation_0-aucpr:0.85975
# [9]	validation_0-aucpr:0.86171
# [10]	validation_0-aucpr:0.86173
# [11]	validation_0-aucpr:0.86329
# [12]	validation_0-aucpr:0.86440
# [13]	validation_0-aucpr:0.86388
# [14]	validation_0-aucpr:0.86476
# [15]	validation_0-aucpr:0.86567
# [16]	validation_0-aucpr:0.86630
# [17]	validation_0-aucpr:0.86682
# [18]	validation_0-aucpr:0.86720
# [19]	validation_0-aucpr:0.86783
# [20]	validation_0-aucpr:0.86827
# [21]	validation_0-aucpr:0.86865
# [22]	validation_0-aucpr:0.86966
# [23]	validation_0-aucpr:0.86987
# [24]	validation_0-aucpr:0.87032
# [25]	validation_0-aucpr:0.87125
# [26]	validation_0-aucpr:0.87194
# [27]	validation_0-aucpr:0.87233
# [28]	validation_0-aucpr:0.87263
# [29]	validation_0-aucpr:0.87252
# [30]	validation_0-aucpr:0.87284
# [31]	validation_0-aucpr:0.87306
# [32]	validation_0-aucpr:0.87371
# [33]	validation_0-aucpr:0.87429
# [34]	validation_0-aucpr:0.87500
# [35]	validation_0-aucpr:0.87541
# [36]	validation_0-aucpr:0.87590
# [37]	validation_0-aucpr:0.87609
# [38]	validation_0-aucpr:0.87652
# [39]	validation_0-aucpr:0.87695
# [40]	validation_0-aucpr:0.87774
# [41]	validation_0-aucpr:0.87766
# [42]	validation_0-aucpr:0.87785
# [43]	validation_0-aucpr:0.87788
# [44]	validation_0-aucpr:0.87851
# [45]	validation_0-aucpr:0.87905
# [46]	validation_0-aucpr:0.87929
# [47]	validation_0-aucpr:0.87927
# [48]	validation_0-aucpr:0.87971
# [49]	validation_0-aucpr:0.87985
# [50]	validation_0-aucpr:0.88020
# [51]	validation_0-aucpr:0.88070
# [52]	validation_0-aucpr:0.88093
# [53]	validation_0-aucpr:0.88118
# [54]	validation_0-aucpr:0.88132
# [55]	validation_0-aucpr:0.88184
# [56]	validation_0-aucpr:0.88204
# [57]	validation_0-aucpr:0.88243
# [58]	validation_0-aucpr:0.88257
# [59]	validation_0-aucpr:0.88283
# [60]	validation_0-aucpr:0.88296
# [61]	validation_0-aucpr:0.88325
# [62]	validation_0-aucpr:0.88347
# [63]	validation_0-aucpr:0.88362
# [64]	validation_0-aucpr:0.88393
# [65]	validation_0-aucpr:0.88390
# [66]	validation_0-aucpr:0.88420
# [67]	validation_0-aucpr:0.88452
# [68]	validation_0-aucpr:0.88461
# [69]	validation_0-aucpr:0.88566
# [70]	validation_0-aucpr:0.88589
# [71]	validation_0-aucpr:0.88586
# [72]	validation_0-aucpr:0.88598
# [73]	validation_0-aucpr:0.88607
# [74]	validation_0-aucpr:0.88648
# [75]	validation_0-aucpr:0.88651
# [76]	validation_0-aucpr:0.88660
# [77]	validation_0-aucpr:0.88687
# [78]	validation_0-aucpr:0.88704
# [79]	validation_0-aucpr:0.88734
# [80]	validation_0-aucpr:0.88766
# [81]	validation_0-aucpr:0.88772
# [82]	validation_0-aucpr:0.88834
# [83]	validation_0-aucpr:0.88853
# [84]	validation_0-aucpr:0.88864
# [85]	validation_0-aucpr:0.88913
# [86]	validation_0-aucpr:0.88934
# [87]	validation_0-aucpr:0.88935
# [88]	validation_0-aucpr:0.88941
# [89]	validation_0-aucpr:0.88936
# [90]	validation_0-aucpr:0.88968
# [91]	validation_0-aucpr:0.88984
# [92]	validation_0-aucpr:0.88977
# [93]	validation_0-aucpr:0.89021
# [94]	validation_0-aucpr:0.89010
# [95]	validation_0-aucpr:0.89046
# [96]	validation_0-aucpr:0.89051
# [97]	validation_0-aucpr:0.89093
# [98]	validation_0-aucpr:0.89131
# [99]	validation_0-aucpr:0.89130
# [100]	validation_0-aucpr:0.89104
# [101]	validation_0-aucpr:0.89134
# [102]	validation_0-aucpr:0.89142
# [103]	validation_0-aucpr:0.89155
# [104]	validation_0-aucpr:0.89157
# [105]	validation_0-aucpr:0.89152
# [106]	validation_0-aucpr:0.89160
# [107]	validation_0-aucpr:0.89216
# [108]	validation_0-aucpr:0.89269
# [109]	validation_0-aucpr:0.89281
# [110]	validation_0-aucpr:0.89312
# [111]	validation_0-aucpr:0.89318
# [112]	validation_0-aucpr:0.89329
# [113]	validation_0-aucpr:0.89371
# [114]	validation_0-aucpr:0.89403
# [115]	validation_0-aucpr:0.89435
# [116]	validation_0-aucpr:0.89449
# [117]	validation_0-aucpr:0.89472
# [118]	validation_0-aucpr:0.89474
# [119]	validation_0-aucpr:0.89484
# [120]	validation_0-aucpr:0.89503
# [121]	validation_0-aucpr:0.89531
# [122]	validation_0-aucpr:0.89510
# [123]	validation_0-aucpr:0.89519
# [124]	validation_0-aucpr:0.89528
# [125]	validation_0-aucpr:0.89530
# [126]	validation_0-aucpr:0.89553
# [127]	validation_0-aucpr:0.89616
# [128]	validation_0-aucpr:0.89632
# [129]	validation_0-aucpr:0.89649
# [130]	validation_0-aucpr:0.89661
# [131]	validation_0-aucpr:0.89680
# [132]	validation_0-aucpr:0.89706
# [133]	validation_0-aucpr:0.89722
# [134]	validation_0-aucpr:0.89731
# [135]	validation_0-aucpr:0.89750
# [136]	validation_0-aucpr:0.89757
# [137]	validation_0-aucpr:0.89791
# [138]	validation_0-aucpr:0.89824
# [139]	validation_0-aucpr:0.89826
# [140]	validation_0-aucpr:0.89841
# [141]	validation_0-aucpr:0.89854
# [142]	validation_0-aucpr:0.89861
# [143]	validation_0-aucpr:0.89873
# [144]	validation_0-aucpr:0.89868
# [145]	validation_0-aucpr:0.89890
# [146]	validation_0-aucpr:0.89889
# [147]	validation_0-aucpr:0.89906
# [148]	validation_0-aucpr:0.89915
# [149]	validation_0-aucpr:0.89933
# [150]	validation_0-aucpr:0.89954
# [151]	validation_0-aucpr:0.89965
# [152]	validation_0-aucpr:0.89986
# [153]	validation_0-aucpr:0.90007
# [154]	validation_0-aucpr:0.90022
# [155]	validation_0-aucpr:0.90034
# [156]	validation_0-aucpr:0.90045
# [157]	validation_0-aucpr:0.90066
# [158]	validation_0-aucpr:0.90071
# [159]	validation_0-aucpr:0.90081
# [160]	validation_0-aucpr:0.90079
# [161]	validation_0-aucpr:0.90087
# [162]	validation_0-aucpr:0.90086
# [163]	validation_0-aucpr:0.90087
# [164]	validation_0-aucpr:0.90089
# [165]	validation_0-aucpr:0.90078
# [166]	validation_0-aucpr:0.90079
# [167]	validation_0-aucpr:0.90094
# [168]	validation_0-aucpr:0.90111
# [169]	validation_0-aucpr:0.90116
# [170]	validation_0-aucpr:0.90122
# [171]	validation_0-aucpr:0.90155
# [172]	validation_0-aucpr:0.90173
# [173]	validation_0-aucpr:0.90187
# [174]	validation_0-aucpr:0.90155
# [175]	validation_0-aucpr:0.90138
# [176]	validation_0-aucpr:0.90150
# [177]	validation_0-aucpr:0.90144
# [178]	validation_0-aucpr:0.90165
# [179]	validation_0-aucpr:0.90167
# [180]	validation_0-aucpr:0.90170
# [181]	validation_0-aucpr:0.90200
# [182]	validation_0-aucpr:0.90209
# [183]	validation_0-aucpr:0.90227
# [184]	validation_0-aucpr:0.90234
# [185]	validation_0-aucpr:0.90231
# [186]	validation_0-aucpr:0.90246
# [187]	validation_0-aucpr:0.90264
# [188]	validation_0-aucpr:0.90271
# [189]	validation_0-aucpr:0.90289
# [190]	validation_0-aucpr:0.90301
# [191]	validation_0-aucpr:0.90335
# [192]	validation_0-aucpr:0.90340
# [193]	validation_0-aucpr:0.90355
# [194]	validation_0-aucpr:0.90345
# [195]	validation_0-aucpr:0.90352
# [196]	validation_0-aucpr:0.90363
# [197]	validation_0-aucpr:0.90366
# [198]	validation_0-aucpr:0.90379
# [199]	validation_0-aucpr:0.90375
# [200]	validation_0-aucpr:0.90384
# [201]	validation_0-aucpr:0.90393
# [202]	validation_0-aucpr:0.90389
# [203]	validation_0-aucpr:0.90400
# [204]	validation_0-aucpr:0.90401
# [205]	validation_0-aucpr:0.90391
# [206]	validation_0-aucpr:0.90400
# [207]	validation_0-aucpr:0.90410
# [208]	validation_0-aucpr:0.90420
# [209]	validation_0-aucpr:0.90434
# [210]	validation_0-aucpr:0.90454
# [211]	validation_0-aucpr:0.90475
# [212]	validation_0-aucpr:0.90478
# [213]	validation_0-aucpr:0.90475
# [214]	validation_0-aucpr:0.90491
# [215]	validation_0-aucpr:0.90499
# [216]	validation_0-aucpr:0.90516
# [217]	validation_0-aucpr:0.90525
# [218]	validation_0-aucpr:0.90537
# [219]	validation_0-aucpr:0.90545
# [220]	validation_0-aucpr:0.90557
# [221]	validation_0-aucpr:0.90567
# [222]	validation_0-aucpr:0.90570
# [223]	validation_0-aucpr:0.90581
# [224]	validation_0-aucpr:0.90601
# [225]	validation_0-aucpr:0.90613
# [226]	validation_0-aucpr:0.90617
# [227]	validation_0-aucpr:0.90629
# [228]	validation_0-aucpr:0.90629
# [229]	validation_0-aucpr:0.90656
# [230]	validation_0-aucpr:0.90664
# [231]	validation_0-aucpr:0.90689
# [232]	validation_0-aucpr:0.90704
# [233]	validation_0-aucpr:0.90718
# [234]	validation_0-aucpr:0.90722
# [235]	validation_0-aucpr:0.90729
# [236]	validation_0-aucpr:0.90734
# [237]	validation_0-aucpr:0.90748
# [238]	validation_0-aucpr:0.90754
# [239]	validation_0-aucpr:0.90766
# [240]	validation_0-aucpr:0.90784
# [241]	validation_0-aucpr:0.90794
# [242]	validation_0-aucpr:0.90808
# [243]	validation_0-aucpr:0.90823
# [244]	validation_0-aucpr:0.90834
# [245]	validation_0-aucpr:0.90849
# [246]	validation_0-aucpr:0.90857
# [247]	validation_0-aucpr:0.90856
# [248]	validation_0-aucpr:0.90879
# [249]	validation_0-aucpr:0.90882
# [250]	validation_0-aucpr:0.90907
# [251]	validation_0-aucpr:0.90911
# [252]	validation_0-aucpr:0.90919
# [253]	validation_0-aucpr:0.90931
# [254]	validation_0-aucpr:0.90933
# [255]	validation_0-aucpr:0.90949
# [256]	validation_0-aucpr:0.90954
# [257]	validation_0-aucpr:0.90954
# [258]	validation_0-aucpr:0.90959
# [259]	validation_0-aucpr:0.90977
# [260]	validation_0-aucpr:0.90977
# [261]	validation_0-aucpr:0.90966
# [262]	validation_0-aucpr:0.90971
# [263]	validation_0-aucpr:0.90978
# [264]	validation_0-aucpr:0.90990
# [265]	validation_0-aucpr:0.91004
# [266]	validation_0-aucpr:0.91008
# [267]	validation_0-aucpr:0.91007
# [268]	validation_0-aucpr:0.91010
# [269]	validation_0-aucpr:0.91005
# [270]	validation_0-aucpr:0.91014
# [271]	validation_0-aucpr:0.91032
# [272]	validation_0-aucpr:0.91032
# [273]	validation_0-aucpr:0.91034
# [274]	validation_0-aucpr:0.91046
# [275]	validation_0-aucpr:0.91052
# [276]	validation_0-aucpr:0.91055
# [277]	validation_0-aucpr:0.91073
# [278]	validation_0-aucpr:0.91075
# [279]	validation_0-aucpr:0.91076
# [280]	validation_0-aucpr:0.91085
# [281]	validation_0-aucpr:0.91091
# [282]	validation_0-aucpr:0.91098
# [283]	validation_0-aucpr:0.91105
# [284]	validation_0-aucpr:0.91108
# [285]	validation_0-aucpr:0.91123
# [286]	validation_0-aucpr:0.91135
# [287]	validation_0-aucpr:0.91152
# [288]	validation_0-aucpr:0.91155
# [289]	validation_0-aucpr:0.91156
# [290]	validation_0-aucpr:0.91159
# [291]	validation_0-aucpr:0.91158
# [292]	validation_0-aucpr:0.91164
# [293]	validation_0-aucpr:0.91167
# [294]	validation_0-aucpr:0.91187
# [295]	validation_0-aucpr:0.91185
# [296]	validation_0-aucpr:0.91181
# [297]	validation_0-aucpr:0.91180
# [298]	validation_0-aucpr:0.91185
# [299]	validation_0-aucpr:0.91204
# [300]	validation_0-aucpr:0.91210
# [301]	validation_0-aucpr:0.91204
# [302]	validation_0-aucpr:0.91221
# [303]	validation_0-aucpr:0.91223
# [304]	validation_0-aucpr:0.91233
# [305]	validation_0-aucpr:0.91232
# [306]	validation_0-aucpr:0.91226
# [307]	validation_0-aucpr:0.91238
# [308]	validation_0-aucpr:0.91242
# [309]	validation_0-aucpr:0.91243
# [310]	validation_0-aucpr:0.91252
# [311]	validation_0-aucpr:0.91257
# [312]	validation_0-aucpr:0.91267
# [313]	validation_0-aucpr:0.91267
# [314]	validation_0-aucpr:0.91275
# [315]	validation_0-aucpr:0.91286
# [316]	validation_0-aucpr:0.91289
# [317]	validation_0-aucpr:0.91300
# [318]	validation_0-aucpr:0.91300
# [319]	validation_0-aucpr:0.91306
# [320]	validation_0-aucpr:0.91309
# [321]	validation_0-aucpr:0.91308
# [322]	validation_0-aucpr:0.91317
# [323]	validation_0-aucpr:0.91324
# [324]	validation_0-aucpr:0.91325
# [325]	validation_0-aucpr:0.91334
# [326]	validation_0-aucpr:0.91329
# [327]	validation_0-aucpr:0.91334
# [328]	validation_0-aucpr:0.91333
# [329]	validation_0-aucpr:0.91340
# [330]	validation_0-aucpr:0.91341
# [331]	validation_0-aucpr:0.91343
# [332]	validation_0-aucpr:0.91345
# [333]	validation_0-aucpr:0.91355
# [334]	validation_0-aucpr:0.91355
# [335]	validation_0-aucpr:0.91355
# [336]	validation_0-aucpr:0.91354
# [337]	validation_0-aucpr:0.91358
# [338]	validation_0-aucpr:0.91359
# [339]	validation_0-aucpr:0.91366
# [340]	validation_0-aucpr:0.91376
# [341]	validation_0-aucpr:0.91373
# [342]	validation_0-aucpr:0.91378
# [343]	validation_0-aucpr:0.91391
# [344]	validation_0-aucpr:0.91391
# [345]	validation_0-aucpr:0.91389
# [346]	validation_0-aucpr:0.91397
# [347]	validation_0-aucpr:0.91401
# [348]	validation_0-aucpr:0.91392
# [349]	validation_0-aucpr:0.91400
# [350]	validation_0-aucpr:0.91408
# [351]	validation_0-aucpr:0.91408
# [352]	validation_0-aucpr:0.91411
# [353]	validation_0-aucpr:0.91413
# [354]	validation_0-aucpr:0.91409
# [355]	validation_0-aucpr:0.91411
# [356]	validation_0-aucpr:0.91416
# [357]	validation_0-aucpr:0.91417
# [358]	validation_0-aucpr:0.91422
# [359]	validation_0-aucpr:0.91428
# [360]	validation_0-aucpr:0.91429
# [361]	validation_0-aucpr:0.91424
# [362]	validation_0-aucpr:0.91416
# [363]	validation_0-aucpr:0.91417
# [364]	validation_0-aucpr:0.91418
# [365]	validation_0-aucpr:0.91422
# [366]	validation_0-aucpr:0.91424
# [367]	validation_0-aucpr:0.91444
# [368]	validation_0-aucpr:0.91450
# [369]	validation_0-aucpr:0.91452
# [370]	validation_0-aucpr:0.91447
# [371]	validation_0-aucpr:0.91451
# [372]	validation_0-aucpr:0.91447
# [373]	validation_0-aucpr:0.91446
# [374]	validation_0-aucpr:0.91455
# [375]	validation_0-aucpr:0.91453
# [376]	validation_0-aucpr:0.91465
# [377]	validation_0-aucpr:0.91465
# [378]	validation_0-aucpr:0.91470
# [379]	validation_0-aucpr:0.91480
# [380]	validation_0-aucpr:0.91478
# [381]	validation_0-aucpr:0.91484
# [382]	validation_0-aucpr:0.91478
# [383]	validation_0-aucpr:0.91480
# [384]	validation_0-aucpr:0.91480
# [385]	validation_0-aucpr:0.91492
# [386]	validation_0-aucpr:0.91491
# [387]	validation_0-aucpr:0.91495
# [388]	validation_0-aucpr:0.91513
# [389]	validation_0-aucpr:0.91512
# [390]	validation_0-aucpr:0.91510
# [391]	validation_0-aucpr:0.91513
# [392]	validation_0-aucpr:0.91517
# [393]	validation_0-aucpr:0.91525
# [394]	validation_0-aucpr:0.91524
# [395]	validation_0-aucpr:0.91525
# [396]	validation_0-aucpr:0.91528
# [397]	validation_0-aucpr:0.91536
# [398]	validation_0-aucpr:0.91536
# [399]	validation_0-aucpr:0.91553
# [400]	validation_0-aucpr:0.91553
# [401]	validation_0-aucpr:0.91552
# [402]	validation_0-aucpr:0.91551
# [403]	validation_0-aucpr:0.91554
# [404]	validation_0-aucpr:0.91553
# [405]	validation_0-aucpr:0.91561
# [406]	validation_0-aucpr:0.91558
# [407]	validation_0-aucpr:0.91560
# [408]	validation_0-aucpr:0.91564
# [409]	validation_0-aucpr:0.91566
# [410]	validation_0-aucpr:0.91566
# [411]	validation_0-aucpr:0.91570
# [412]	validation_0-aucpr:0.91566
# [413]	validation_0-aucpr:0.91570
# [414]	validation_0-aucpr:0.91578
# [415]	validation_0-aucpr:0.91584
# [416]	validation_0-aucpr:0.91595
# [417]	validation_0-aucpr:0.91600
# [418]	validation_0-aucpr:0.91598
# [419]	validation_0-aucpr:0.91606
# [420]	validation_0-aucpr:0.91600
# [421]	validation_0-aucpr:0.91594
# [422]	validation_0-aucpr:0.91605
# [423]	validation_0-aucpr:0.91607
# [424]	validation_0-aucpr:0.91604
# [425]	validation_0-aucpr:0.91608
# [426]	validation_0-aucpr:0.91610
# [427]	validation_0-aucpr:0.91609
# [428]	validation_0-aucpr:0.91616
# [429]	validation_0-aucpr:0.91622
# [430]	validation_0-aucpr:0.91622
# [431]	validation_0-aucpr:0.91622
# [432]	validation_0-aucpr:0.91635
# [433]	validation_0-aucpr:0.91634
# [434]	validation_0-aucpr:0.91631
# [435]	validation_0-aucpr:0.91634
# [436]	validation_0-aucpr:0.91634
# [437]	validation_0-aucpr:0.91635
# [438]	validation_0-aucpr:0.91638
# [439]	validation_0-aucpr:0.91644
# [440]	validation_0-aucpr:0.91648
# [441]	validation_0-aucpr:0.91650
# [442]	validation_0-aucpr:0.91650
# [443]	validation_0-aucpr:0.91652
# [444]	validation_0-aucpr:0.91649
# [445]	validation_0-aucpr:0.91650
# [446]	validation_0-aucpr:0.91654
# [447]	validation_0-aucpr:0.91654
# [448]	validation_0-aucpr:0.91655
# [449]	validation_0-aucpr:0.91657
# [450]	validation_0-aucpr:0.91661
# [451]	validation_0-aucpr:0.91662
# [452]	validation_0-aucpr:0.91664
# [453]	validation_0-aucpr:0.91670
# [454]	validation_0-aucpr:0.91675
# [455]	validation_0-aucpr:0.91677
# [456]	validation_0-aucpr:0.91684
# [457]	validation_0-aucpr:0.91689
# [458]	validation_0-aucpr:0.91689
# [459]	validation_0-aucpr:0.91689
# [460]	validation_0-aucpr:0.91683
# [461]	validation_0-aucpr:0.91683
# [462]	validation_0-aucpr:0.91689
# [463]	validation_0-aucpr:0.91691
# [464]	validation_0-aucpr:0.91691
# [465]	validation_0-aucpr:0.91691
# [466]	validation_0-aucpr:0.91691
# [467]	validation_0-aucpr:0.91700
# [468]	validation_0-aucpr:0.91700
# [469]	validation_0-aucpr:0.91695
# [470]	validation_0-aucpr:0.91699
# [471]	validation_0-aucpr:0.91697
# [472]	validation_0-aucpr:0.91698
# [473]	validation_0-aucpr:0.91704
# [474]	validation_0-aucpr:0.91703
# [475]	validation_0-aucpr:0.91699
# [476]	validation_0-aucpr:0.91699
# [477]	validation_0-aucpr:0.91700
# [478]	validation_0-aucpr:0.91706
# [479]	validation_0-aucpr:0.91708
# [480]	validation_0-aucpr:0.91709
# [481]	validation_0-aucpr:0.91715
# [482]	validation_0-aucpr:0.91715
# [483]	validation_0-aucpr:0.91712
# [484]	validation_0-aucpr:0.91709
# [485]	validation_0-aucpr:0.91710
# [486]	validation_0-aucpr:0.91712
# [487]	validation_0-aucpr:0.91714
# [488]	validation_0-aucpr:0.91715
# [489]	validation_0-aucpr:0.91719
# [490]	validation_0-aucpr:0.91720
# [491]	validation_0-aucpr:0.91725
# [492]	validation_0-aucpr:0.91726
# [493]	validation_0-aucpr:0.91732
# [494]	validation_0-aucpr:0.91732
# [495]	validation_0-aucpr:0.91725
# [496]	validation_0-aucpr:0.91729
# [497]	validation_0-aucpr:0.91728
# [498]	validation_0-aucpr:0.91734
# [499]	validation_0-aucpr:0.91730
# [500]	validation_0-aucpr:0.91732
# [501]	validation_0-aucpr:0.91732
# [502]	validation_0-aucpr:0.91733
# [503]	validation_0-aucpr:0.91731
# [504]	validation_0-aucpr:0.91741
# [505]	validation_0-aucpr:0.91742
# [506]	validation_0-aucpr:0.91742
# [507]	validation_0-aucpr:0.91737
# [508]	validation_0-aucpr:0.91737
# [509]	validation_0-aucpr:0.91738
# [510]	validation_0-aucpr:0.91736
# [511]	validation_0-aucpr:0.91739
# [512]	validation_0-aucpr:0.91746
# [513]	validation_0-aucpr:0.91750
# [514]	validation_0-aucpr:0.91753
# [515]	validation_0-aucpr:0.91755
# [516]	validation_0-aucpr:0.91754
# [517]	validation_0-aucpr:0.91750
# [518]	validation_0-aucpr:0.91750
# [519]	validation_0-aucpr:0.91747
# [520]	validation_0-aucpr:0.91747
# [521]	validation_0-aucpr:0.91749
# [522]	validation_0-aucpr:0.91751
# [523]	validation_0-aucpr:0.91748
# [524]	validation_0-aucpr:0.91750
#
# ==================================================
# DEPARTMENT-SPECIFIC ANALYSIS
# ==================================================
#
# HR Department Insights:
# Top 3 attrition risk drivers for HR Department:
# - Work_Environment_Satisfaction: SHAP value = 0.3089
# - Gender_Male: SHAP value = 0.2830
# - Years_Since_Last_Promotion: SHAP value = 0.2714
#
# IT Department Insights:
# Top 3 attrition risk drivers for IT Department:
# - Relationship_with_Manager: SHAP value = 0.5765
# - Marital_Status_Married: SHAP value = 0.4556
# - Job_Role_Manager: SHAP value = 0.3721
#
# Marketing Department Insights:
# Top 3 attrition risk drivers for Marketing Department:
# - Years_at_Company: SHAP value = 0.2814
# - Job_Role_Executive: SHAP value = 0.1948
# - Job_Role_Manager: SHAP value = 0.1891
#
# Sales Department Insights:
# Top 3 attrition risk drivers for Sales Department:
# - Gender_Male: SHAP value = 0.3271
# - Overtime: SHAP value = 0.2340
# - Job_Role_Executive: SHAP value = 0.2151

# %% [markdown]
# # streamlit implementation

# %% [markdown]
# Serialization and Deserialization

# %%
#create path to save models and data files (if not already created)
model_data_dir = Path('')
model_data_dir.mkdir(parents=True, exist_ok=True)  # Create directory and parents if needed

# 1. Save model
model_path = model_data_dir / 'xgboost_attrition_model.pkl'
with open(model_path, 'wb') as f:
    pickle.dump(final_model, f)

# 2. Save data files
# CSV files (overwrite if exists)
pd.DataFrame(X_test, columns=data['feature_names']).to_csv(model_data_dir / 'X_test.csv', index=False)
y_test.to_csv(model_data_dir / 'y_test.csv', index=False)

# NumPy arrays
y_pred = final_model.predict(X_test)
np.save(model_data_dir / 'y_pred.npy', y_pred)
if hasattr(final_model, 'predict_proba'):
    y_proba = final_model.predict_proba(X_test)
    np.save(model_data_dir / 'y_proba.npy', y_proba)

# XGBoost-specific versions
pd.DataFrame(X_test, columns=data['feature_names']).to_csv(model_data_dir / 'X_test_xgboost.csv', index=False)
y_test.to_csv(model_data_dir / 'y_test_xgboost.csv', index=False)
np.save(model_data_dir / 'xgboost_y_pred.npy', y_pred)

print(f"All files saved to: {model_data_dir.resolve()}")
# Out:
# All files saved to: C:\Users\NITS\Downloads\NitishKumarJaiswal_20044140_Artifact
